# %% [markdown]
# ###  Import numpy,pandas,data visualization libraries

# %%
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ###  Import the dataset

# %%
dataset=pd.read_csv('CAR.csv')

# %%
dataset
# Out:
#      Horsepower  Acceleration
# 0            82          19.4
# 1           130          12.0
# 2           165          11.5
# 3           150          11.0
# 4           150          12.0
# ..          ...           ...
# 401          90          17.3
# 402          86          15.6
# 403          52          24.6
# 404          84          11.6
# 405          79          18.6
#
# [406 rows x 2 columns]

# %% [markdown]
# ###  Understand the dataset

# %%
dataset.shape
# Out:
# (406, 2)

# %%
dataset.head()
# Out:
#    Horsepower  Acceleration
# 0          82          19.4
# 1         130          12.0
# 2         165          11.5
# 3         150          11.0
# 4         150          12.0

# %% [markdown]
# ### Visualize the dataset

# %%
plt.rcParams["figure.figsize"]=[14,6]
dataset.plot(x='Horsepower',y='Acceleration',style='.',color='blue',markersize=8)
plt.title('Horsepower vs Acceleration')
plt.xlabel('Horsepower')
plt.ylabel('Acceleration')
plt.grid()
plt.show()

# %% [markdown]
# ###  Corelation

# %%
dataset.corr()
# Out:
#               Horsepower  Acceleration
# Horsepower      1.000000     -0.682047
# Acceleration   -0.682047      1.000000

# %% [markdown]
# ### Divide the dataset into training and test set

# %%
x=dataset.iloc[:,:1].values

# %%
y=dataset.iloc[:,1:].values

# %%
x
# Out:
# array([[ 82],
#        [130],
#        [165],
#        [150],
#        [150],
#        [140],
#        [198],
#        [220],
#        [215],
#        [225],
#        [190],
#        [115],
#        [165],
#        [153],
#        [175],
#        [175],
#        [170],
#        [160],
#        [140],
#        [150],
#        [225],
#        [ 95],
#        [ 95],
#        [ 97],
#        [ 85],
#        [ 88],
#        [ 46],
#        [ 87],
#        [ 90],
#        [ 95],
#        [113],
#        [ 90],
#        [215],
#        [200],
#        [210],
#        [193],
#        [ 88],
#        [ 90],
#        [ 95],
#        [  0],
#        [ 48],
#        [100],
#        [105],
#        [100],
#        [ 88],
#        [100],
#        [165],
#        [175],
#        [153],
#        [150],
#        [180],
#        [170],
#        [175],
#        [110],
#        [ 72],
#        [100],
#        [ 88],
#        [ 86],
#        [ 90],
#        [ 70],
#        [ 76],
#        [ 65],
# ...

# %%
y
# Out:
# array([[19.4],
#        [12. ],
#        [11.5],
#        [11. ],
#        [12. ],
#        [10.5],
#        [10. ],
#        [ 9. ],
#        [ 8.5],
#        [10. ],
#        [ 8.5],
#        [17.5],
#        [11.5],
#        [11. ],
#        [10.5],
#        [11. ],
#        [10. ],
#        [ 8. ],
#        [ 8. ],
#        [ 9.5],
#        [10. ],
#        [15. ],
#        [15.5],
#        [15.5],
#        [16. ],
#        [14.5],
#        [20.5],
#        [17.5],
#        [14.5],
#        [17.5],
#        [12.5],
#        [15. ],
#        [14. ],
#        [15. ],
#        [13.5],
#        [18.5],
#        [14.5],
#        [15.5],
#        [14. ],
#        [19. ],
#        [20. ],
#        [13. ],
#        [15.5],
#        [15.5],
#        [15.5],
#        [15.5],
#        [12. ],
#        [11.5],
#        [13.5],
#        [13. ],
#        [11.5],
#        [12. ],
#        [12. ],
#        [13.5],
#        [19. ],
#        [15. ],
#        [14.5],
#        [14. ],
# ...

# %% [markdown]
# ### Import the function

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (324, 1)

# %%
x_test.shape
# Out:
# (82, 1)

# %%
y_train.shape
# Out:
# (324, 1)

# %%
y_test.shape
# Out:
# (82, 1)

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction

# %%
y_pred=lm.predict(x_test)

# %%
y_pred
# Out:
# array([[16.90425362],
#        [11.63882198],
#        [16.85846726],
#        [13.69920827],
#        [20.33823078],
#        [14.61493552],
#        [13.51606283],
#        [12.55454922],
#        [17.36211724],
#        [10.49416293],
#        [16.49217636],
#        [17.36211724],
#        [14.29443098],
#        [16.12588547],
#        [12.78348103],
#        [15.75959457],
#        [15.98852638],
#        [15.94274002],
#        [17.13318543],
#        [15.89695365],
#        [16.90425362],
#        [13.97392645],
#        [15.30173095],
#        [15.75959457],
#        [17.27054452],
#        [16.30903091],
#        [15.53066276],
#        [14.01971281],
#        [12.32561741],
#        [14.84386733],
#        [16.90425362],
#        [16.67532181],
#        [16.30903091],
#        [13.47027646],
#        [16.21745819],
#        [13.24134465],
#        [17.95733995],
#        [16.21745819],
#        [16.53796272],
#        [17.04161271],
#        [16.30903091],
# ...

# %% [markdown]
# ### Check our prediction

# %%
check=pd.DataFrame(x_test,columns=["Horesepower"])

# %%
check['Acceleration Actual']=y_test

# %%
check['Acceleration Predicted']=y_pred

# %%
check
# Out:
#     Horesepower  Acceleration Actual  Acceleration Predicted
# 0            75                 16.0               16.904254
# 1           190                 12.2               11.638822
# 2            76                 14.5               16.858467
# 3           145                 13.7               13.699208
# 4             0                 17.0               20.338231
# ..          ...                  ...                     ...
# 77          225                 10.0               10.036299
# 78          180                 12.1               12.096686
# 79          175                 10.5               12.325617
# 80           68                 16.5               17.224758
# 81           70                 14.2               17.133185
#
# [82 rows x 3 columns]

# %% [markdown]
# ### Visualize the regressor line

# %%
plt.rcParams["figure.figsize"]=[14,6]
dataset.plot(x='Horsepower',y='Acceleration',style='.',color='blue',markersize=8)
plt.plot(x_test,y_pred,color='red')
plt.title('Horsepower vs Acceleration')
plt.xlabel('Horsepower')
plt.ylabel('Acceleration')
plt.grid()
plt.show()
